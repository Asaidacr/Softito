# %%
hava_yagmurlu=True
if hava_yagmurlu:
  print("yağmurluk al")
else:
   ("güneş gözlüğünü takabilirsin")
# Out:
# yağmurluk al

# %% [markdown]
# # 🐍 Temel Python Komutları - Alıştırma Defteri
#
# Bu defterde Python'un temel konularını öğrenecek ve pratik sorularla kendinizi geliştireceksiniz.
#
# ---

# %% [markdown]
# ## 1️⃣ Değişkenler ve Veri Tipleri

# %% [markdown]
# ### 🔸 Soru 1:
# Aşağıdaki değişkenleri tanımlayın ve her birinin tipini `type()` fonksiyonu ile yazdırın:
# - `sehir`: "Ankara" (string)
# - `nüfus`: 5700000 (integer)
# - `sicaklik`: 23.5 (float)
# - `yagmur_yagıyor`: False (boolean)

# %%
# Cevabınızı buraya yazın:

sehir = "Ankara"
nüfus = 5700000
sicaklik = 23.5
yagmur_yagıyor = False

print("sehir değişkeninin tipi:", type(sehir))
print("nüfus değişkeninin tipi:", type(nüfus))
print("sicaklik değişkeninin tipi:", type(sicaklik))
print("yagmur_yagıyor değişkeninin tipi:", type(yagmur_yagıyor))
# Out:
# sehir değişkeninin tipi: <class 'str'>
# nüfus değişkeninin tipi: <class 'int'>
# sicaklik değişkeninin tipi: <class 'float'>
# yagmur_yagıyor değişkeninin tipi: <class 'bool'>

# %% [markdown]
# ### 🔸 Soru 2:
# Bir değişkeni `int`'ten `float`'a, `float`'tan `str`'e dönüştürün ve sonuçları yazdırın.
#
# Örnek: `sayi = 42` → `float(sayi)` → `str(float(sayi))`

# %%
# Cevabınzı buraya yazın
sayi = 42
print("1. orjinal hali:", sayi)
print("   Tipi:", type(sayi))
print("-" * 30)

sayi_float = float(sayi)
print("2. Floata dönüştürülmüş hali:", sayi_float)
print("   Tipi:", type(sayi_float))
print("-" * 30)

sayi_str = str(sayi_float)
print("3. Stringe dönüştürülmüş hali:", sayi_str)
print("   Tipi:", type(sayi_str))
# Out:
# 1. orjinal hali: 42
#    Tipi: <class 'int'>
# ------------------------------
# 2. Floata dönüştürülmüş hali: 42.0
#    Tipi: <class 'float'>
# ------------------------------
# 3. Stringe dönüştürülmüş hali: 42.0
#    Tipi: <class 'str'>

# %% [markdown]
# ---
# ## 2️⃣ Operatörler

# %%
# Örnek: Aritmetik operatörler
a = 10
b = 3

# %% [markdown]
# ### 🔸 Soru 3:
# Kullanıcıdan alınan iki sayı olduğunu varsayın: `x = 17`, `y = 5`
# - Toplamlarını, farklarını ve çarpımlarını yazdırın.
# - 17'nin 5'e bölümünden kalanı yazdırın.
# - 2'nin 8. kuvvetini hesaplayın.

# %%
# Cevabınızı buraya yazın:
x=17
y=5

print("toplam:", x+y)
print("çarpım:", x*y)
print("farkları:", x-y)
print("17 nin 5 e bölümünden kalan:", 17%5)
print("2 nin 8. kuvveti:", 2**8)
# Out:
# toplam: 22
# çarpım: 85
# farkları: 12
# 17 nin 5 e bölümünden kalan: 2
# 2 nin 8. kuvveti: 256

# %% [markdown]
# ### 🔸 Soru 4:
# Karşılaştırma operatörlerini kullanarak aşağıdaki ifadelerin sonuçlarını (True/False) yazdırın:
# - 10 > 5
# - 3 == 3.0
# - "elma" != "armut"
# - 7 <= 7

# %%
# Cevabınızı buraya yazın:
print(10>5)
print(3==3.0)
print("elma"!="armut")
print(7<=7)
# Out:
# True
# True
# True
# True

# %% [markdown]
# ---
# ## 3️⃣ String (Metin) İşlemleri

# %%
# Örnek: String metodları
metin = "Merhaba Python!"

print(metin.upper())       # Büyük harf
print(metin.lower())       # Küçük harf
print(metin.replace("Python", "Dünya"))  # Değiştirme
print(len(metin))          # Uzunluk
print(metin[0:7])          # Dilimleme

# %% [markdown]
# ### 🔸 Soru 5:
# `cumle = "  python programlama dili çok güçlüdür  "` değişkeni için:
# - Baştaki ve sondaki boşlukları temizleyin (`.strip()`)
# - İlk harfini büyük yapın (`.capitalize()`)
# - Kaç kelimeden oluştuğunu bulun (`.split()` ve `len()` kullanın)
# - "güçlü" kelimesinin cümlede olup olmadığını kontrol edin (`in` operatörü)

# %%
# Cevabınızı buraya yazın:
cumle = " python programlama dili çok güçlüdür "

# 1. Boşlukları temizleme
temiz_cumle = cumle.strip()
print(f"Temizlenmiş: '{temiz_cumle}'")

# 2. İlk harfi büyük yapma
print("Büyük Harf:", temiz_cumle.capitalize())

# 3. Kelime sayısını bulma
kelime_sayisi = len(temiz_cumle.split())
print("Kelime Sayısı:", kelime_sayisi)

# 4. Kelime kontrolü
var_mi = "güçlü" in temiz_cumle
print("'güçlü' kelimesi var mı?:", var_mi)
# Out:
# Temizlenmiş: 'python programlama dili çok güçlüdür'
# Büyük Harf: Python programlama dili çok güçlüdür
# Kelime Sayısı: 5
# 'güçlü' kelimesi var mı?: True

# %% [markdown]
# ### 🔸 Soru 6 (f-string):
# Ad, soyad ve yaş bilgilerini f-string kullanarak şu formatta yazdırın:
#
# `"Merhaba, ben [AD] [SOYAD]. [YAŞ] yaşındayım."`

# %%
# Cevabınızı buraya yazın:
ad = "Said"
soyad = "Acer"
yas = 26

print(f"Merhaba, ben {ad} {soyad}. {yas} yaşındayım.")
# Out:
# Merhaba, ben Said Acer. 26 yaşındayım.

# %% [markdown]
# ---
# ## 4️⃣ Koşullu İfadeler (if / elif / else)

# %%
# Örnek
puan = 75

if puan >= 90:
    print("AA")
elif puan >= 80:
    print("BA")
elif puan >= 70:
    print("BB")
elif puan >= 60:
    print("CB")
else:
    print("Başarısız")

# %% [markdown]
# ### 🔸 Soru 7:
# Bir sayının pozitif, negatif ya da sıfır olduğunu kontrol eden if-elif-else bloğu yazın.

# %%
sayi = -7

if sayi < 0:
  print("Sayı negatif")
elif sayi == 0:
  print("Sayı sıfırdır")
else:
  print("Sayı pozitiftir")
# Out:
# Sayı negatif

# %% [markdown]
# ### 🔸 Soru 8:
# Bir sayının 2'ye ve 3'e tam bölünüp bölünmediğini kontrol edin. 4 farklı durum vardır:
# - Hem 2'ye hem 3'e bölünebilir
# - Sadece 2'ye bölünebilir
# - Sadece 3'e bölünebilir
# - Hiçbirine bölünemiyor

# %%
# Cevabınızı buraya yazın:
n = 12

if sayi % 2 == 0 and sayi % 3 == 0:
    print("Hem 2'ye hem 3'e bölünebilir")
elif sayi % 2 == 0:
    print("Sadece 2'ye bölünebilir")
elif sayi % 3 == 0:
    print("Sadece 3'e bölünebilir")
else:
    print("Hiçbirine bölünemiyor")
# Out:
# Hiçbirine bölünemiyor

# %% [markdown]
# ---
# ## 5️⃣ Döngüler (for / while)

# %%
# Örnek: for döngüsü
for i in range(1, 6):
    print(f"{i}. adım")

print("---")

# Örnek: while döngüsü
sayac = 0
while sayac < 3:
    print(f"Sayaç: {sayac}")
    sayac += 1

# %% [markdown]
# ### 🔸 Soru 9:
# `for` döngüsü ile 1'den 10'a kadar olan sayıların toplamını hesaplayın.

# %%
# Cevabınızı buraya yazın:
toplam =0
for sayi  in range(1,11) :
  toplam += sayi

  print("1'den 10 a kadar olan sayıların toplamı:", toplam)
# Out:
# 1'den 10 a kadar olan sayıların toplamı: 1
# 1'den 10 a kadar olan sayıların toplamı: 3
# 1'den 10 a kadar olan sayıların toplamı: 6
# 1'den 10 a kadar olan sayıların toplamı: 10
# 1'den 10 a kadar olan sayıların toplamı: 15
# 1'den 10 a kadar olan sayıların toplamı: 21
# 1'den 10 a kadar olan sayıların toplamı: 28
# 1'den 10 a kadar olan sayıların toplamı: 36
# 1'den 10 a kadar olan sayıların toplamı: 45
# 1'den 10 a kadar olan sayıların toplamı: 55

# %% [markdown]
# ### 🔸 Soru 10:
# `while` döngüsü ile kullanıcının girdiği sayıya (n=5) kadar Fibonacci dizisini yazdırın.
#
# Örnek çıktı: `0, 1, 1, 2, 3`

# %%
# Cevabınızı buraya yazın:
n = 5
a, b = 0, 1
sayac = 0

while sayac < n:
    print(a, end=" " if sayac < n - 1 else "")
    a, b = b, a + b
    sayac += 1
# Out:
# 0 1 1 2 3

# %% [markdown]
# ### 🔸 Soru 11 (İç İçe Döngü):
# 5x5 çarpım tablosunu yazdırın. Her satır şu formatta olsun:
#
# `1x1=1  1x2=2  1x3=3 ...`

# %%
# Cevabınızı buraya yazın:
for i in range(1, 4):
    for j in range(1, 4):
        print(f"{i}x{j}={i*j}", end=" ")
    print()
# Out:
# 1x1=1 1x2=2 1x3=3
# 2x1=2 2x2=4 2x3=6
# 3x1=3 3x2=6 3x3=9

# %% [markdown]
# ---
# ## 6️⃣ Listeler

# %%
# Örnek
meyveler = ["elma", "armut", "çilek", "muz"]

print(meyveler[0])          # İlk eleman
print(meyveler[-1])         # Son eleman
print(meyveler[1:3])        # Dilimleme
meyveler.append("kivi")     # Ekleme
meyveler.remove("armut")    # Silme
print(meyveler)

# %% [markdown]
# ### 🔸 Soru 12:
# Aşağıdaki listede:
# - En büyük ve en küçük elemanı bulun
# - Listeyi sıralayın
# - 7 sayısının listede kaç kez geçtiğini bulun
# - Listeyi tersine çevirin

# %%
# Cevabınızı buraya yazın:
sayilar = [3, 7, 1, 9, 7, 4, 7, 2, 8]

print("En Büyük:", max(sayilar))
print("En Küçük:", min(sayilar))

sayilar.sort()
print("Sıralı Liste:", sayilar)

print("7 sayısının tekrarı:", sayilar.count(7))

sayilar.reverse()
print("Ters Çevrilmiş Liste:", sayilar)
# Out:
# En Büyük: 9
# En Küçük: 1
# Sıralı Liste: [1, 2, 3, 4, 7, 7, 7, 8, 9]
# 7 sayısının tekrarı: 3
# Ters Çevrilmiş Liste: [9, 8, 7, 7, 7, 4, 3, 2, 1]

# %% [markdown]
# ### 🔸 Soru 13 (List Comprehension):
# List comprehension kullanarak:
# - 1-20 arasındaki çift sayıların listesini oluşturun
# - Bir kelime listesindeki 4'ten uzun kelimeleri filtreleyin

# %%
# Cevabınızı buraya yazın:
kelimeler = ["at", "kaplan", "it", "fil", "kedi", "aslan", "köpek"]

uzun_kelimeler = [kelime for kelime in kelimeler if len(kelime) > 4]

print(uzun_kelimeler)
# Out:
# ['kaplan', 'aslan', 'köpek']

# %% [markdown]
# ---
# ## 7️⃣ Sözlükler (Dictionary)

# %%
# Örnek
ogrenci = {
    "ad": "Ali",
    "soyad": "Kaya",
    "yas": 20,
    "notlar": [85, 90, 78]
}

print(ogrenci["ad"])
print(ogrenci.get("yas"))
ogrenci["bolum"] = "Bilgisayar Mühendisliği"
print(ogrenci.keys())
print(ogrenci.values())

# %% [markdown]
# ### 🔸 Soru 14:
# Bir kitap sözlüğü oluşturun (`baslik`, `yazar`, `yil`, `sayfa_sayisi`) ve:
# - Tüm anahtar-değer çiftlerini döngüyle yazdırın
# - `fiyat` anahtarı ekleyin
# - `yazar` anahtarını silin

# %%
# Cevabınızı buraya yazın:

kitap = {
    "baslik": "1984",
    "yazar": "George Orwell",
    "yil": 1949,
    "sayfa_sayisi": 352
}

for anahtar, deger in kitap.items():
    print(f"{anahtar.capitalize()}: {deger}")

kitap["fiyat"] = 85.50

del kitap["yazar"]


print("-" * 20)
print("Sözlüğün Güncel Hali:", kitap)
# Out:
# Baslik: 1984
# Yazar: George Orwell
# Yil: 1949
# Sayfa_sayisi: 352
# --------------------
# Sözlüğün Güncel Hali: {'baslik': '1984', 'yil': 1949, 'sayfa_sayisi': 352, 'fiyat': 85.5}

# %% [markdown]
# ---
# ## 8️⃣ Fonksiyonlar

# %%
# Örnek
def selamla(isim, nezaket="Merhaba"):
    return f"{nezaket}, {isim}!"

print(selamla("Ayşe"))
print(selamla("Mehmet", "İyi günler"))

# %% [markdown]
# ### 🔸 Soru 15:
# Bir sayının asal olup olmadığını kontrol eden `asal_mi(n)` fonksiyonu yazın.
# - 1'den 20'ye kadar olan asal sayıları bu fonksiyonu kullanarak yazdırın.

# %%
def asal_mi(n):
    if n < 2:
        return False
    for i in range(2, int(n**0.5) + 1):
        if n % i == 0:
            return False
    return True

print("1-20 arasındaki asal sayılar:")
for sayi in range(1, 21):
    if asal_mi(sayi):
        print(sayi, end=" ")
# Out:
# 1-20 arasındaki asal sayılar:
# 2 3 5 7 11 13 17 19

# %% [markdown]
# ### 🔸 Soru 16:
# Bir listenin ortalamasını, en büyük ve en küçük elemanını döndüren `liste_istatistik(liste)` fonksiyonu yazın.
# Fonksiyon 3 değer döndürsün: `(ortalama, minimum, maksimum)`

# %%
# Cevabınızı buraya yazın:
def liste_istatistik(liste):
    ortalama = sum(liste) / len(liste)
    minimum = min(liste)
    maksimum = max(liste)
    return ortalama, minimum, maksimum

test = [4, 8, 15, 16, 23, 42]
ort, min_deger, max_deger = liste_istatistik(test)

print(f"Ortalama: {ort}")
print(f"Minimum: {min_deger}")
print(f"Maksimum: {max_deger}")
# Out:
# Ortalama: 18.0
# Minimum: 4
# Maksimum: 42

# %% [markdown]
# ---
# ## 9️⃣ Hata Yönetimi (try / except)

# %%
# Örnek
try:
    sonuc = 10 / 0
except ZeroDivisionError:
    print("Sıfıra bölme hatası!")
except Exception as e:
    print(f"Beklenmeyen hata: {e}")
finally:
    print("İşlem tamamlandı.")

# %% [markdown]
# ### 🔸 Soru 17:
# Kullanıcıdan bir sayı alındığını varsayın (`girdi = "abc"`).
# Bu değeri int'e çevirmeye çalışırken `ValueError` hatası oluşabilir.
# try-except ile bunu yakalayan ve anlamlı bir mesaj veren kod yazın.

# %%
# Cevabınızı buraya yazın:
girdi = "abc"

try:
    sayi = int(girdi)
    print("Dönüştürülen sayı:", sayi)
except ValueError:
    print("Hata: Girdiğiniz değer bir tam sayı değil! Lütfen sadece rakam kullanın.")
# Out:
# Hata: Girdiğiniz değer bir tam sayı değil! Lütfen sadece rakam kullanın.

# %% [markdown]
# ---
# ## 🔟 Bonus: Kapsamlı Uygulama

# %% [markdown]
# ### 🔸 Soru 18 (Bütünleştirici):
# Bir **not defteri uygulaması** yazın:
# - `notlar` adında boş bir liste oluşturun
# - `not_ekle(metin)` fonksiyonu: Notu listeye ekler
# - `not_listele()` fonksiyonu: Tüm notları numaralandırarak yazdırır
# - `not_sil(index)` fonksiyonu: Verilen indexteki notu siler, hatalı index için hata mesajı verir
#
# Fonksiyonları test edin: 3 not ekleyin, listeleyin, ortadakini silin, tekrar listeleyin.

# %%
notlar = []

def not_ekle(metin):
    notlar.append(metin)

def not_listele():
    if not notlar:
        print("Not defteri boş.")
    else:
        for index, metin in enumerate(notlar, start=1):
            print(f"{index}. {metin}")

def not_sil(index):
    try:

        silinen = notlar.pop(index - 1)
        print(f"'{silinen}' notu silindi.")
    except IndexError:
        print(f"Hata: {index} numaralı bir not bulunamadı!")

# --- TEST BÖLÜMÜ ---

# 1. 3 not ekleyin
not_ekle("Marketten süt al")
not_ekle("Python ödevini bitir")
not_ekle("Saat 19:00'da toplantı var")

# 2. Listeleyin
print("--- Notlar Listeleniyor ---")
not_listele()

# 3. Ortadakini silin (2. not)
print("\n--- 2. Not Siliniyor ---")
not_sil(2)

# 4. Tekrar listeleyin
print("\n--- Güncel Not Listesi ---")
not_listele()
# Out:
# --- Notlar Listeleniyor ---
# 1. Marketten süt al
# 2. Python ödevini bitir
# 3. Saat 19:00'da toplantı var
#
# --- 2. Not Siliniyor ---
# 'Python ödevini bitir' notu silindi.
#
# --- Güncel Not Listesi ---
# 1. Marketten süt al
# 2. Saat 19:00'da toplantı var

# %% [markdown]
# ---
# ## 📊 Özet Çizelgesi
#
# | Konu | Sorular | Tamamlandı mı? |
# |------|---------|----------------|
# | Değişkenler & Tipler | 1, 2 | ☐ |
# | Operatörler | 3, 4 | ☐ |
# | String İşlemleri | 5, 6 | ☐ |
# | Koşullar | 7, 8 | ☐ |
# | Döngüler | 9, 10, 11 | ☐ |
# | Listeler | 12, 13 | ☐ |
# | Sözlükler | 14 | ☐ |
# | Fonksiyonlar | 15, 16 | ☐ |
# | Hata Yönetimi | 17 | ☐ |
# | Bütünleştirici | 18 | ☐ |
#
# > 💡 **İpucu:** Takıldığınız yerde `help()` fonksiyonunu veya Python dokümantasyonunu kullanın!
